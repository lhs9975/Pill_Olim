# %%
import tensorflow as tf
from tensorflow.python.client import device_lib
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    # 텐서플로가 첫 번째 GPU만 사용하도록 제한
    try:
        tf.config.set_visible_devices(gpus[0], 'GPU')
    except RuntimeError as e:
        # 프로그램 시작시에 접근 가능한 장치가 설정되어야만 합니다
        print(e)

# %%
import os
from tensorflow.keras import models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Flatten, Dense, Dropout
from tensorflow.keras import optimizers


import numpy as np
import matplotlib.pyplot as plt
import os

# %%
pwd
# Out:
# 'e:\\Pill Project\\code\\Model'

# %%
# 데이터셋 디렉터리 경로
dataset_dir = 'E:\Pill Project\split_data'
train_dir = os.path.join(dataset_dir, 'train')
validation_dir = os.path.join(dataset_dir, 'valid')
# test_dir = os.path.join(dataset_dir, 'test')

# 사진 크기
image_width = 224
image_height = 224

# ImageDataGenerator 초기화
# 0~1 사이로 숫자값 변경
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)
# test_datagen = ImageDataGenerator(rescale=1./255)

# 훈련셋 제너레이터
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(image_width, image_height),
    batch_size=32,
    class_mode='categorical')

# 검증셋 제너레이터
validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(image_width, image_height),
    batch_size=32,
    class_mode='categorical')

# 테스트셋 제너레이터
# test_generator = test_datagen.flow_from_directory(
#     test_dir,
#     target_size=(image_width, image_height),
#     batch_size=16,
#     class_mode='categorical')
# Out:
# Found 5019 images belonging to 18 classes.
# Found 1256 images belonging to 18 classes.

# %%
# 훈련셋에서 배치를 생성
for data_batch, labels_batch in train_generator:
    break

# %%
# 데이터 배치의 크기
# (배치개수, 이미지너비, 이미지높이, RGB채널)
data_batch.shape
# Out:
# (32, 224, 224, 3)

# %%
# 라벨 배치의 크기
# (배치개수, 카테고리개수)
labels_batch.shape
# Out:
# (32, 18)

# %%
# 첫 번째 이미지 출력
image = data_batch[0]

plt.imshow(image)
plt.show()

# %% [markdown]
# # 기존 모델

# %%
# 기존 모델

model = Sequential()

# Layer 1
model.add(Conv2D(96, (11, 11), strides=(4, 4), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
model.add(BatchNormalization())

# Layer 2
model.add(Conv2D(256, (5, 5), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
model.add(BatchNormalization())

# Layer 3
model.add(Conv2D(384, (3, 3), activation='relu', padding='same'))

# Layer 4
model.add(Conv2D(384, (3, 3), activation='relu', padding='same'))

# Layer 5
model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
model.add(BatchNormalization())

# Flatten
model.add(Flatten())

# Layer 6
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

# Layer 7
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

# Output layer
model.add(Dense(18, activation='softmax'))

# %% [markdown]
# # 두번째 모델

# %%
# 두 번째 모델
# Layer 5 Conv2D, pool_size 변경
model = Sequential()

# Layer 1
model.add(Conv2D(96, (11, 11), strides=(4, 4), activation='relu', input_shape=(224, 224, 3)))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
model.add(BatchNormalization())

# Layer 2
model.add(Conv2D(256, (5, 5), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))
model.add(BatchNormalization())

# Layer 3
model.add(Conv2D(384, (3, 3), activation='relu', padding='same'))

# Layer 4
model.add(Conv2D(384, (3, 3), activation='relu', padding='same'))

# Layer 5, pool_size(3, 3) -> pool_size(2, 2)로 변경
model.add(Conv2D(256, (2, 2), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(BatchNormalization())

# Flatten
model.add(Flatten())

# Layer 6
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

# Layer 7
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

# Output layer, 클래스 개수
model.add(Dense(400, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 54, 54, 96)        34944
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 26, 26, 96)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 26, 26, 96)        384
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 26, 26, 256)       614656
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 256)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 12, 12, 256)       1024
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 384)       885120
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 384)       1327488
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 12, 12, 256)       884992
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 5, 5, 256)         1024
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              26218496
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 18)                73746
# =================================================================
# Total params: 46,823,186
# Trainable params: 46,821,970
# Non-trainable params: 1,216
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
batch_size = 32
epochs = 60

# %%
# Train the model
history = model.fit(train_generator,
          steps_per_epoch=train_generator.samples // batch_size,
          epochs=epochs,
          validation_data=validation_generator,
          validation_steps=validation_generator.samples // batch_size)
# Out:
# Epoch 1/60
# 156/156 [==============================] - 539s 3s/step - loss: 1.0313 - accuracy: 0.6948 - val_loss: 5.9645 - val_accuracy: 0.1362
# Epoch 2/60
# 156/156 [==============================] - 318s 2s/step - loss: 0.5758 - accuracy: 0.8017 - val_loss: 4.6819 - val_accuracy: 0.1667
# Epoch 3/60
# 156/156 [==============================] - 294s 2s/step - loss: 0.4481 - accuracy: 0.8380 - val_loss: 2.9125 - val_accuracy: 0.3782
# Epoch 4/60
# 156/156 [==============================] - 292s 2s/step - loss: 0.3783 - accuracy: 0.8715 - val_loss: 2.1841 - val_accuracy: 0.5681
# Epoch 5/60
# 156/156 [==============================] - 291s 2s/step - loss: 0.3197 - accuracy: 0.8903 - val_loss: 0.9033 - val_accuracy: 0.7452
# Epoch 6/60
# 156/156 [==============================] - 290s 2s/step - loss: 0.2939 - accuracy: 0.8945 - val_loss: 0.3669 - val_accuracy: 0.8678
# Epoch 7/60
# 156/156 [==============================] - 290s 2s/step - loss: 0.2500 - accuracy: 0.9118 - val_loss: 0.3201 - val_accuracy: 0.8694
# Epoch 8/60
# 156/156 [==============================] - 288s 2s/step - loss: 0.2257 - accuracy: 0.9236 - val_loss: 0.8166 - val_accuracy: 0.7837
# Epoch 9/60
# 156/156 [==============================] - 292s 2s/step - loss: 0.1903 - accuracy: 0.9298 - val_loss: 0.7138 - val_accuracy: 0.8598
# Epoch 10/60
# 156/156 [==============================] - 289s 2s/step - loss: 0.1476 - accuracy: 0.9439 - val_loss: 0.2758 - val_accuracy: 0.9046
# Epoch 11/60
# 156/156 [==============================] - 288s 2s/step - loss: 0.1400 - accuracy: 0.9489 - val_loss: 2.1946 - val_accuracy: 0.6731
# Epoch 12/60
# 156/156 [==============================] - 289s 2s/step - loss: 0.1519 - accuracy: 0.9481 - val_loss: 0.2757 - val_accuracy: 0.9006
# Epoch 13/60
# 156/156 [==============================] - 287s 2s/step - loss: 0.1546 - accuracy: 0.9497 - val_loss: 0.9067 - val_accuracy: 0.7780
# Epoch 14/60
# 156/156 [==============================] - 288s 2s/step - loss: 0.1265 - accuracy: 0.9605 - val_loss: 0.1533 - val_accuracy: 0.9423
# Epoch 15/60
# 156/156 [==============================] - 288s 2s/step - loss: 0.0856 - accuracy: 0.9681 - val_loss: 2.8020 - val_accuracy: 0.5160
# Epoch 16/60
# 156/156 [==============================] - 289s 2s/step - loss: 0.0895 - accuracy: 0.9685 - val_loss: 1.5386 - val_accuracy: 0.7091
# Epoch 17/60
# 156/156 [==============================] - 290s 2s/step - loss: 0.0628 - accuracy: 0.9781 - val_loss: 0.6165 - val_accuracy: 0.8381
# Epoch 18/60
# 156/156 [==============================] - 292s 2s/step - loss: 0.0594 - accuracy: 0.9775 - val_loss: 0.8676 - val_accuracy: 0.8365
# Epoch 19/60
# 156/156 [==============================] - 288s 2s/step - loss: 0.0714 - accuracy: 0.9759 - val_loss: 5.9500 - val_accuracy: 0.5769
# Epoch 20/60
# 156/156 [==============================] - 286s 2s/step - loss: 0.1139 - accuracy: 0.9657 - val_loss: 0.9131 - val_accuracy: 0.8173
# Epoch 21/60
# 156/156 [==============================] - 288s 2s/step - loss: 0.0983 - accuracy: 0.9681 - val_loss: 0.2832 - val_accuracy: 0.9062
# Epoch 22/60
# 156/156 [==============================] - 289s 2s/step - loss: 0.0656 - accuracy: 0.9765 - val_loss: 0.1852 - val_accuracy: 0.9383
# Epoch 23/60
# 156/156 [==============================] - 289s 2s/step - loss: 0.0657 - accuracy: 0.9771 - val_loss: 0.1987 - val_accuracy: 0.9359
# Epoch 24/60
# 156/156 [==============================] - 287s 2s/step - loss: 0.0972 - accuracy: 0.9665 - val_loss: 1.5269 - val_accuracy: 0.8037
# Epoch 25/60
# 156/156 [==============================] - 288s 2s/step - loss: 0.0623 - accuracy: 0.9791 - val_loss: 4.2235 - val_accuracy: 0.6538
# Epoch 26/60
# 156/156 [==============================] - 337s 2s/step - loss: 0.0620 - accuracy: 0.9816 - val_loss: 2.2402 - val_accuracy: 0.7300
# Epoch 27/60
# 156/156 [==============================] - 338s 2s/step - loss: 0.0761 - accuracy: 0.9783 - val_loss: 0.0383 - val_accuracy: 0.9856
# Epoch 28/60
# 156/156 [==============================] - 324s 2s/step - loss: 0.0571 - accuracy: 0.9797 - val_loss: 0.1409 - val_accuracy: 0.9535
# Epoch 29/60
# 156/156 [==============================] - 323s 2s/step - loss: 0.0563 - accuracy: 0.9840 - val_loss: 0.4632 - val_accuracy: 0.8942
# Epoch 30/60
# 156/156 [==============================] - 316s 2s/step - loss: 0.0659 - accuracy: 0.9803 - val_loss: 3.2708 - val_accuracy: 0.6731
# Epoch 31/60
# 156/156 [==============================] - 316s 2s/step - loss: 0.0585 - accuracy: 0.9816 - val_loss: 1.4429 - val_accuracy: 0.7556
# Epoch 32/60
# 156/156 [==============================] - 317s 2s/step - loss: 0.0992 - accuracy: 0.9697 - val_loss: 3.9275 - val_accuracy: 0.5769
# Epoch 33/60
# 156/156 [==============================] - 320s 2s/step - loss: 0.0669 - accuracy: 0.9781 - val_loss: 1.6279 - val_accuracy: 0.8205
# Epoch 34/60
# 156/156 [==============================] - 322s 2s/step - loss: 0.0818 - accuracy: 0.9818 - val_loss: 1.2182 - val_accuracy: 0.8494
# Epoch 35/60
# 156/156 [==============================] - 324s 2s/step - loss: 0.0963 - accuracy: 0.9737 - val_loss: 1.2445 - val_accuracy: 0.7476
# Epoch 36/60
# 156/156 [==============================] - 304s 2s/step - loss: 0.0629 - accuracy: 0.9785 - val_loss: 0.2966 - val_accuracy: 0.9207
# Epoch 37/60
# 156/156 [==============================] - 309s 2s/step - loss: 0.0390 - accuracy: 0.9860 - val_loss: 0.1262 - val_accuracy: 0.9679
# Epoch 38/60
# 156/156 [==============================] - 295s 2s/step - loss: 0.0414 - accuracy: 0.9864 - val_loss: 0.6381 - val_accuracy: 0.8726
# Epoch 39/60
# 156/156 [==============================] - 300s 2s/step - loss: 0.0450 - accuracy: 0.9850 - val_loss: 0.2658 - val_accuracy: 0.9279
# Epoch 40/60
# 156/156 [==============================] - 318s 2s/step - loss: 0.0293 - accuracy: 0.9904 - val_loss: 0.4427 - val_accuracy: 0.9079
# Epoch 41/60
# 156/156 [==============================] - 321s 2s/step - loss: 0.0394 - accuracy: 0.9864 - val_loss: 0.2272 - val_accuracy: 0.9407
# Epoch 42/60
# 156/156 [==============================] - 329s 2s/step - loss: 0.0315 - accuracy: 0.9904 - val_loss: 1.0613 - val_accuracy: 0.8766
# Epoch 43/60
# 156/156 [==============================] - 317s 2s/step - loss: 0.0258 - accuracy: 0.9904 - val_loss: 0.1011 - val_accuracy: 0.9663
# Epoch 44/60
# 156/156 [==============================] - 318s 2s/step - loss: 0.0103 - accuracy: 0.9960 - val_loss: 0.2653 - val_accuracy: 0.9431
# Epoch 45/60
# 156/156 [==============================] - 319s 2s/step - loss: 0.0538 - accuracy: 0.9836 - val_loss: 1.3642 - val_accuracy: 0.8349
# Epoch 46/60
# 156/156 [==============================] - 326s 2s/step - loss: 0.0442 - accuracy: 0.9868 - val_loss: 0.5128 - val_accuracy: 0.9054
# Epoch 47/60
# 156/156 [==============================] - 328s 2s/step - loss: 0.0230 - accuracy: 0.9924 - val_loss: 0.2776 - val_accuracy: 0.9199
# Epoch 48/60
# 156/156 [==============================] - 320s 2s/step - loss: 0.0548 - accuracy: 0.9830 - val_loss: 1.9125 - val_accuracy: 0.8277
# Epoch 49/60
# 156/156 [==============================] - 313s 2s/step - loss: 0.0578 - accuracy: 0.9830 - val_loss: 3.0152 - val_accuracy: 0.7188
# Epoch 50/60
# 156/156 [==============================] - 308s 2s/step - loss: 0.0806 - accuracy: 0.9810 - val_loss: 2.2598 - val_accuracy: 0.7933
# Epoch 51/60
# 156/156 [==============================] - 309s 2s/step - loss: 0.0491 - accuracy: 0.9876 - val_loss: 0.0193 - val_accuracy: 0.9920
# Epoch 52/60
# 156/156 [==============================] - 300s 2s/step - loss: 0.0273 - accuracy: 0.9922 - val_loss: 0.2644 - val_accuracy: 0.9367
# Epoch 53/60
# 156/156 [==============================] - 292s 2s/step - loss: 0.0297 - accuracy: 0.9926 - val_loss: 0.3941 - val_accuracy: 0.9111
# Epoch 54/60
# 156/156 [==============================] - 292s 2s/step - loss: 0.0243 - accuracy: 0.9916 - val_loss: 1.1820 - val_accuracy: 0.8357
# Epoch 55/60
# 156/156 [==============================] - 290s 2s/step - loss: 0.0323 - accuracy: 0.9892 - val_loss: 0.7042 - val_accuracy: 0.8662
# Epoch 56/60
# 156/156 [==============================] - 297s 2s/step - loss: 0.0231 - accuracy: 0.9930 - val_loss: 0.0392 - val_accuracy: 0.9872
# Epoch 57/60
# 156/156 [==============================] - 291s 2s/step - loss: 0.0286 - accuracy: 0.9888 - val_loss: 6.1169 - val_accuracy: 0.6498
# Epoch 58/60
# 156/156 [==============================] - 293s 2s/step - loss: 0.0334 - accuracy: 0.9888 - val_loss: 4.6116 - val_accuracy: 0.7524
# Epoch 59/60
# 156/156 [==============================] - 292s 2s/step - loss: 0.0403 - accuracy: 0.9876 - val_loss: 0.8136 - val_accuracy: 0.8662
# Epoch 60/60
# 156/156 [==============================] - 295s 2s/step - loss: 0.0369 - accuracy: 0.9912 - val_loss: 0.4488 - val_accuracy: 0.9207

# %%
loss = history.history['loss'] # training loss
val_loss = history.history['val_loss'] # validation loss

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Add maximum and minimum values for training loss
max_loss = max(loss)
min_loss = min(loss)
max_loss_epoch = loss.index(max_loss) + 1
min_loss_epoch = loss.index(min_loss) + 1

plt.annotate(f'Train Max: {max_loss:.4f}', xy=(max_loss_epoch, max_loss), xytext=(max_loss_epoch, max_loss+1),
             arrowprops=dict(facecolor='black', arrowstyle='->'), bbox=dict(facecolor='white', edgecolor='black', boxstyle='round'), horizontalalignment='center')
plt.annotate(f'Train Min: {min_loss:.4f}', xy=(min_loss_epoch, min_loss), xytext=(min_loss_epoch, min_loss+1),
             arrowprops=dict(facecolor='black', arrowstyle='->'), bbox=dict(facecolor='white', edgecolor='black', boxstyle='round'), horizontalalignment='center')

# Add maximum and minimum values for validation loss
max_val_loss = max(val_loss)
min_val_loss = min(val_loss)    
max_val_loss_epoch = val_loss.index(max_val_loss) + 1
min_val_loss_epoch = val_loss.index(min_val_loss) + 1

plt.annotate(f'Val Max: {max_val_loss:.4f}', xy=(max_val_loss_epoch, max_val_loss), xytext=(max_val_loss_epoch+2, max_val_loss+1),
             arrowprops=dict(facecolor='black', arrowstyle='->'), bbox=dict(facecolor='white', edgecolor='black', boxstyle='round'), horizontalalignment='center')
plt.annotate(f'Val Min: {min_val_loss:.4f}', xy=(min_val_loss_epoch, min_val_loss), xytext=(min_val_loss_epoch, min_val_loss+1.3),
             arrowprops=dict(facecolor='black', arrowstyle='->'), bbox=dict(facecolor='white', edgecolor='black', boxstyle='round'), horizontalalignment='center')

plt.ylim(0, 7)  # Set the y-axis limits between 0 and 1

plt.show()

# %%
acc = history.history['accuracy'] # training accuracy
val_acc = history.history['val_accuracy'] # validation accuracy

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Add maximum and minimum values for training accuracy
max_acc = max(acc)
min_acc = min(acc)
max_acc_epoch = acc.index(max_acc) + 1
min_acc_epoch = acc.index(min_acc) + 1

plt.annotate(f'Train Max: {max_acc:.4f}', xy=(max_acc_epoch, max_acc), xytext=(max_acc_epoch, max_acc-0.1),
             arrowprops=dict(facecolor='black', arrowstyle='->'), bbox=dict(facecolor='white', edgecolor='black', boxstyle='round'), horizontalalignment='center')
plt.annotate(f'Train Min: {min_acc:.4f}', xy=(min_acc_epoch, min_acc), xytext=(min_acc_epoch, min_acc+0.1),
             arrowprops=dict(facecolor='black', arrowstyle='->'), bbox=dict(facecolor='white', edgecolor='black', boxstyle='round'), horizontalalignment='center')

# Add maximum and minimum values for validation accuracy
max_val_acc = max(val_acc)
min_val_acc = min(val_acc)
max_val_acc_epoch = val_acc.index(max_val_acc) + 1
min_val_acc_epoch = val_acc.index(min_val_acc) + 1

plt.annotate(f'Val Max: {max_val_acc:.4f}', xy=(max_val_acc_epoch, max_val_acc), xytext=(max_val_acc_epoch-10, max_val_acc-0.2),
             arrowprops=dict(facecolor='black', arrowstyle='->'), bbox=dict(facecolor='white', edgecolor='black', boxstyle='round'), horizontalalignment='center')
plt.annotate(f'Val Min: {min_val_acc:.4f}', xy=(min_val_acc_epoch, min_val_acc), xytext=(min_val_acc_epoch-10, min_val_acc+0.2),
             arrowprops=dict(facecolor='black', arrowstyle='->'), bbox=dict(facecolor='white', edgecolor='black', boxstyle='round'), horizontalalignment='center')

plt.show()

# %%
# 모델 저장
# model.save('E:\Pill Project\model/AlexNet_10_31_data18_batch16_epoch30_m2.h5')

SAVED_MODEL_PATH = 'E:\Pill Project\model_h5/AlexNet_11_07_data18_batch32_epoch60_m1.h5'
export_path = os.path.join(SAVED_MODEL_PATH)

tf.keras.models.save_model(
  model,
  export_path,
  overwrite=True,
  include_optimizer=True,
  save_format=None,
  signatures=None,
  options=None
)
print('\nSaved model:')
# Out:
# Saved model:

# %%
# 저장된 모델 파일 로드
model = models.load_model('c:/Users/LEE/Desktop/app/assets/AlexNet_10_31_data18_batch16_epoch30_m1.tflite')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# e:\Pill Project\code\Model\AlexNet_Train.ipynb 셀 20 line 2
#       <a href='vscode-notebook-cell:/e%3A/Pill%20Project/code/Model/AlexNet_Train.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> # 저장된 모델 파일 로드
# ----> <a href='vscode-notebook-cell:/e%3A/Pill%20Project/code/Model/AlexNet_Train.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a> model = models.load_model('c:/Users/LEE/Desktop/app/assets/AlexNet_10_31_data18_batch16_epoch30_m1.tflite')
#
# File c:\Users\LEE\anaconda3\envs\cnn\lib\site-packages\tensorflow\python\keras\saving\save.py:206, in load_model(filepath, custom_objects, compile, options)
#     204       filepath = path_to_string(filepath)
#     205       if isinstance(filepath, str):
# --> 206         return saved_model_load.load(filepath, compile, options)
#     208 raise IOError(
#     209     'Unable to load model. Filepath is not an hdf5 file (or h5py is not '
#     210     'available) or SavedModel.')
#
# File c:\Users\LEE\anaconda3\envs\cnn\lib\site-packages\tensorflow\python\keras\saving\saved_model\load.py:121, in load(path, compile, options)
#     116 # TODO(kathywu): Add saving/loading of optimizer, compiled losses and metrics.
#     117 # TODO(kathywu): Add code to load from objects that contain all endpoints
#     118
#     119 # Look for metadata file or parse the SavedModel
#     120 metadata = saved_metadata_pb2.SavedMetadata()
# --> 121 meta_graph_def = loader_impl.parse_saved_model(path).meta_graphs[0]
#     122 object_graph_def = meta_graph_def.object_graph_def
#     123 path_to_metadata_pb = os.path.join(path, constants.SAVED_METADATA_PATH)
#
# File c:\Users\LEE\anaconda3\envs\cnn\lib\site-packages\tensorflow\python\saved_model\loader_impl.py:113, in parse_saved_model(export_dir)
#     111     raise IOError("Cannot parse file %s: %s." % (path_to_pbtxt, str(e)))
#     112 else:
# --> 113   raise IOError(
#     114       "SavedModel file does not exist at: %s%s{%s|%s}" %
#     115       (export_dir, os.path.sep, constants.SAVED_MODEL_FILENAME_PBTXT,
#     116        constants.SAVED_MODEL_FILENAME_PB))
#
# OSError: SavedModel file does not exist at: c:/Users/LEE/Desktop/app/assets/AlexNet_10_31_data18_batch16_epoch30_m1.tflite\{saved_model.pbtxt|saved_model.pb}

# %%
# 테스트셋 평가
results = model.evaluate(test_generator)
results
# Out:
# 405/405 [==============================] - 105s 258ms/step - loss: 0.3269 - accuracy: 0.9201
# [0.3269144296646118, 0.9200617074966431]

# %%
# 테스트셋 예측
results = model.predict(test_generator)
results
# Out:
# array([[0.0000000e+00, 6.7517599e-34, 0.0000000e+00, ..., 0.0000000e+00,
#         5.4453811e-36, 6.4441246e-26],
#        [4.7104237e-30, 2.4400703e-26, 3.8407118e-29, ..., 1.4998909e-21,
#         1.2567253e-27, 1.2149968e-20],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 1.7676101e-31],
#        ...,
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 5.4061440e-34, 0.0000000e+00, ..., 0.0000000e+00,
#         1.3848214e-26, 2.4400465e-38],
#        [2.7035816e-23, 1.8130349e-10, 1.7338660e-20, ..., 9.5538569e-30,
#         6.7365394e-28, 1.1803977e-27]], dtype=float32)

# %%
# 예측값을 인덱스로 변환
results = np.argmax(results, 1)
results
# Out:
# array([386, 280, 194, ...,  98, 102, 117], dtype=int64)

# %%
# 테스트셋에서 배치를 생성
for data_batch, labels_batch in test_generator:
    break
    
# 테스트셋의 첫 번째 이미지 출력
image = data_batch[0]

plt.imshow(image)
plt.show()

# %%
# 테스트셋 배치 데이터를 예측
results = model.predict(data_batch)

# 테스트셋의 첫 번째 라벨 이름 출력
labels_list[np.argmax(results[0])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\Pill Project\code\Model\AlexNet_Train.ipynb 셀 25 line 5
#       <a href='vscode-notebook-cell:/e%3A/Pill%20Project/code/Model/AlexNet_Train.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a> results = model.predict(data_batch)
#       <a href='vscode-notebook-cell:/e%3A/Pill%20Project/code/Model/AlexNet_Train.ipynb#X33sZmlsZQ%3D%3D?line=3'>4</a> # 테스트셋의 첫 번째 라벨 이름 출력
# ----> <a href='vscode-notebook-cell:/e%3A/Pill%20Project/code/Model/AlexNet_Train.ipynb#X33sZmlsZQ%3D%3D?line=4'>5</a> labels_list[np.argmax(results[0])]
#
# NameError: name 'labels_list' is not defined
