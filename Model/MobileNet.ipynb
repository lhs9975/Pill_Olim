# %%
import tensorflow as tf
from tensorflow.python.client import device_lib
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    # 텐서플로가 첫 번째 GPU만 사용하도록 제한
    try:
        tf.config.set_visible_devices(gpus[0], 'GPU')
    except RuntimeError as e:
        # 프로그램 시작시에 접근 가능한 장치가 설정되어야만 합니다
        print(e)

# %%
import os
from tensorflow.keras import models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Flatten, Dense, Dropout
from tensorflow.keras import optimizers
from tensorflow.keras.applications.mobilenet import MobileNet

import numpy as np
import matplotlib.pyplot as plt
import os

# %%
pwd
# Out:
# 'e:\\Pill Project\\code\\Model'

# %%
# 데이터셋 디렉터리 경로
dataset_dir = 'E:\\Pill Project\\half_data'
train_dir = os.path.join(dataset_dir, 'train')
validation_dir = os.path.join(dataset_dir, 'valid')
# test_dir = os.path.join(dataset_dir, 'test')

# 사진 크기
image_width = 224
image_height = 224

# ImageDataGenerator 초기화
# 0~1 사이로 숫자값 변경
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)
# test_datagen = ImageDataGenerator(rescale=1./255)

# 훈련셋 제너레이터
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(image_width, image_height),
    batch_size=64,
    class_mode='categorical')

# 검증셋 제너레이터
validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(image_width, image_height),
    batch_size=64,
    class_mode='categorical')

# # 테스트셋 제너레이터
# test_generator = test_datagen.flow_from_directory(
#     test_dir,
#     target_size=(image_width, image_height),
#     batch_size=64,
#     class_mode='categorical')
# Out:
# Found 207360 images belonging to 400 classes.
# Found 51840 images belonging to 400 classes.

# %%
# 훈련셋에서 배치를 생성
for data_batch, labels_batch in train_generator:
    break

# %%
# 데이터 배치의 크기
# (배치개수, 이미지너비, 이미지높이, RGB채널)
data_batch.shape
# Out:
# (64, 224, 224, 3)

# %%
# 라벨 배치의 크기
# (배치개수, 카테고리개수)
labels_batch.shape
# Out:
# (64, 400)

# %%
# 첫 번째 이미지 출력
image = data_batch[0]

plt.imshow(image)
plt.show()

# %% [markdown]
# # 기존 모델

# %%
base_model = MobileNet(include_top=False, alpha=1.0, weights=None, input_shape=(224, 224, 3), classes=400)

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(400, activation='softmax')  # 400개의 클래스에 대한 출력 레이어
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenet_1.00_224 (Function (None, 7, 7, 1024)        3228864
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               262400
# _________________________________________________________________
# dense_1 (Dense)              (None, 400)               102800
# =================================================================
# Total params: 3,594,064
# Trainable params: 3,572,176
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer=optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# 모델 학습을 위한 설정
epochs = 120  # 여기서 원하는 에폭 수로 설정하세요.

# 모델 학습
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size
)
# Out:
# Epoch 1/120
# 3240/3240 [==============================] - 3205s 987ms/step - loss: 4.2073 - accuracy: 0.1077 - val_loss: 3.0769 - val_accuracy: 0.1798
# Epoch 2/120
# 3240/3240 [==============================] - 771s 238ms/step - loss: 1.7495 - accuracy: 0.4906 - val_loss: 1.8046 - val_accuracy: 0.4623
# Epoch 3/120
# 3240/3240 [==============================] - 750s 232ms/step - loss: 1.0994 - accuracy: 0.6584 - val_loss: 114.3397 - val_accuracy: 0.0025
# Epoch 4/120
# 3240/3240 [==============================] - 760s 234ms/step - loss: 0.8324 - accuracy: 0.7323 - val_loss: 48.2428 - val_accuracy: 0.0066
# Epoch 5/120
# 3240/3240 [==============================] - 758s 234ms/step - loss: 0.6743 - accuracy: 0.7786 - val_loss: 0.7578 - val_accuracy: 0.7441
# Epoch 6/120
# 3240/3240 [==============================] - 760s 234ms/step - loss: 0.5603 - accuracy: 0.8131 - val_loss: 5.5992 - val_accuracy: 0.1604
# Epoch 7/120
# 3240/3240 [==============================] - 752s 232ms/step - loss: 0.4688 - accuracy: 0.8421 - val_loss: 0.6363 - val_accuracy: 0.7819
# Epoch 8/120
# 3240/3240 [==============================] - 773s 239ms/step - loss: 0.3990 - accuracy: 0.8643 - val_loss: 0.7311 - val_accuracy: 0.7578
# Epoch 9/120
# 3240/3240 [==============================] - 769s 237ms/step - loss: 0.3504 - accuracy: 0.8803 - val_loss: 0.5407 - val_accuracy: 0.8159
# Epoch 10/120
# 3240/3240 [==============================] - 782s 241ms/step - loss: 0.3058 - accuracy: 0.8949 - val_loss: 0.6052 - val_accuracy: 0.7917
# Epoch 11/120
# 3240/3240 [==============================] - 776s 239ms/step - loss: 0.2721 - accuracy: 0.9056 - val_loss: 0.4089 - val_accuracy: 0.8603
# Epoch 12/120
# 3240/3240 [==============================] - 761s 235ms/step - loss: 0.2465 - accuracy: 0.9151 - val_loss: 0.3712 - val_accuracy: 0.8754
# Epoch 13/120
# 3240/3240 [==============================] - 750s 231ms/step - loss: 0.2213 - accuracy: 0.9234 - val_loss: 0.5985 - val_accuracy: 0.8005
# Epoch 14/120
# 3240/3240 [==============================] - 774s 239ms/step - loss: 0.2007 - accuracy: 0.9311 - val_loss: 2.5585 - val_accuracy: 0.4673
# Epoch 15/120
# 3240/3240 [==============================] - 759s 234ms/step - loss: 0.1870 - accuracy: 0.9355 - val_loss: 163.6861 - val_accuracy: 0.0040
# Epoch 16/120
# 3240/3240 [==============================] - 773s 238ms/step - loss: 0.1699 - accuracy: 0.9413 - val_loss: 0.2621 - val_accuracy: 0.9076
# Epoch 17/120
# 3240/3240 [==============================] - 748s 231ms/step - loss: 0.1573 - accuracy: 0.9461 - val_loss: 0.2064 - val_accuracy: 0.9282
# Epoch 18/120
# 3240/3240 [==============================] - 793s 245ms/step - loss: 0.1466 - accuracy: 0.9492 - val_loss: 67.6601 - val_accuracy: 0.0126
# Epoch 19/120
# 3240/3240 [==============================] - 807s 249ms/step - loss: 0.1381 - accuracy: 0.9521 - val_loss: 43.6866 - val_accuracy: 0.0234
# Epoch 20/120
# 3240/3240 [==============================] - 832s 257ms/step - loss: 0.1285 - accuracy: 0.9555 - val_loss: 0.1939 - val_accuracy: 0.9338
# Epoch 21/120
# 3240/3240 [==============================] - 824s 254ms/step - loss: 0.1224 - accuracy: 0.9572 - val_loss: 0.2393 - val_accuracy: 0.9182
# Epoch 22/120
# 3240/3240 [==============================] - 799s 247ms/step - loss: 0.1145 - accuracy: 0.9604 - val_loss: 0.2597 - val_accuracy: 0.9117
# Epoch 23/120
# 3240/3240 [==============================] - 775s 239ms/step - loss: 0.1084 - accuracy: 0.9624 - val_loss: 0.2266 - val_accuracy: 0.9230
# Epoch 24/120
# 3240/3240 [==============================] - 776s 240ms/step - loss: 0.1016 - accuracy: 0.9650 - val_loss: 0.2299 - val_accuracy: 0.9245
# Epoch 25/120
# 3240/3240 [==============================] - 813s 251ms/step - loss: 0.0976 - accuracy: 0.9660 - val_loss: 1.8568 - val_accuracy: 0.6193
# Epoch 26/120
# 3240/3240 [==============================] - 790s 244ms/step - loss: 0.0908 - accuracy: 0.9689 - val_loss: 0.9000 - val_accuracy: 0.7666
# Epoch 27/120
# 3240/3240 [==============================] - 795s 245ms/step - loss: 0.0886 - accuracy: 0.9693 - val_loss: 0.4140 - val_accuracy: 0.8718
# Epoch 28/120
# 3240/3240 [==============================] - 778s 240ms/step - loss: 0.0844 - accuracy: 0.9713 - val_loss: 0.2200 - val_accuracy: 0.9289
# Epoch 29/120
# 3240/3240 [==============================] - 767s 237ms/step - loss: 0.0802 - accuracy: 0.9722 - val_loss: 204.9532 - val_accuracy: 0.0037
# Epoch 30/120
# 3240/3240 [==============================] - 795s 245ms/step - loss: 0.0760 - accuracy: 0.9740 - val_loss: 30.7386 - val_accuracy: 0.0648
# Epoch 31/120
# 3240/3240 [==============================] - 809s 250ms/step - loss: 0.0741 - accuracy: 0.9745 - val_loss: 79.4947 - val_accuracy: 0.0147
# Epoch 32/120
# 3240/3240 [==============================] - 784s 242ms/step - loss: 0.0690 - accuracy: 0.9763 - val_loss: 77.2915 - val_accuracy: 0.0153
# Epoch 33/120
# 3240/3240 [==============================] - 780s 241ms/step - loss: 0.0694 - accuracy: 0.9760 - val_loss: 100.9121 - val_accuracy: 0.0101
# Epoch 34/120
# 3240/3240 [==============================] - 781s 241ms/step - loss: 0.0659 - accuracy: 0.9775 - val_loss: 189.8648 - val_accuracy: 0.0025
# Epoch 35/120
# 3240/3240 [==============================] - 780s 241ms/step - loss: 0.0620 - accuracy: 0.9787 - val_loss: 56.1017 - val_accuracy: 0.0221
# Epoch 36/120
# 3240/3240 [==============================] - 789s 243ms/step - loss: 0.0602 - accuracy: 0.9796 - val_loss: 0.1306 - val_accuracy: 0.9561
# Epoch 37/120
# 3240/3240 [==============================] - 897s 277ms/step - loss: 0.0598 - accuracy: 0.9793 - val_loss: 212.4546 - val_accuracy: 0.0025
# Epoch 38/120
# 3240/3240 [==============================] - 796s 246ms/step - loss: 0.0575 - accuracy: 0.9803 - val_loss: 46.4835 - val_accuracy: 0.0311
# Epoch 39/120
# 3240/3240 [==============================] - 800s 247ms/step - loss: 0.0557 - accuracy: 0.9808 - val_loss: 211.2207 - val_accuracy: 0.0025
# Epoch 40/120
# 3240/3240 [==============================] - 801s 247ms/step - loss: 0.0538 - accuracy: 0.9818 - val_loss: 179.0994 - val_accuracy: 0.0038
# Epoch 41/120
# 3240/3240 [==============================] - 806s 249ms/step - loss: 0.0523 - accuracy: 0.9818 - val_loss: 207.9656 - val_accuracy: 0.0025
# Epoch 42/120
# 3240/3240 [==============================] - 789s 243ms/step - loss: 0.0510 - accuracy: 0.9825 - val_loss: 0.1969 - val_accuracy: 0.9382
# Epoch 43/120
# 3240/3240 [==============================] - 777s 240ms/step - loss: 0.0489 - accuracy: 0.9835 - val_loss: 204.8642 - val_accuracy: 0.0035
# Epoch 44/120
# 3240/3240 [==============================] - 783s 242ms/step - loss: 0.0479 - accuracy: 0.9838 - val_loss: 0.2460 - val_accuracy: 0.9242
# Epoch 45/120
# 3240/3240 [==============================] - 786s 243ms/step - loss: 0.0454 - accuracy: 0.9843 - val_loss: 0.1246 - val_accuracy: 0.9606
# Epoch 46/120
# 3240/3240 [==============================] - 802s 247ms/step - loss: 0.0452 - accuracy: 0.9848 - val_loss: 1.9425 - val_accuracy: 0.6243
# Epoch 47/120
# 3240/3240 [==============================] - 779s 240ms/step - loss: 0.0428 - accuracy: 0.9854 - val_loss: 220.2887 - val_accuracy: 0.0029
# Epoch 48/120
# 3240/3240 [==============================] - 779s 240ms/step - loss: 0.0438 - accuracy: 0.9853 - val_loss: 0.0919 - val_accuracy: 0.9688
# Epoch 49/120
# 3240/3240 [==============================] - 773s 239ms/step - loss: 0.0428 - accuracy: 0.9856 - val_loss: 168.0454 - val_accuracy: 0.0062
# Epoch 50/120
# 3240/3240 [==============================] - 772s 238ms/step - loss: 0.0409 - accuracy: 0.9859 - val_loss: 78.9272 - val_accuracy: 0.0187
# Epoch 51/120
# 3240/3240 [==============================] - 790s 244ms/step - loss: 0.0391 - accuracy: 0.9867 - val_loss: 0.1178 - val_accuracy: 0.9638
# Epoch 52/120
# 3240/3240 [==============================] - 888s 274ms/step - loss: 0.0392 - accuracy: 0.9867 - val_loss: 0.1160 - val_accuracy: 0.9624
# Epoch 53/120
# 3240/3240 [==============================] - 890s 274ms/step - loss: 0.0376 - accuracy: 0.9872 - val_loss: 0.1011 - val_accuracy: 0.9681
# Epoch 54/120
# 3240/3240 [==============================] - 775s 239ms/step - loss: 0.0379 - accuracy: 0.9871 - val_loss: 138.0275 - val_accuracy: 0.0083
# Epoch 55/120
# 3240/3240 [==============================] - 767s 237ms/step - loss: 0.0366 - accuracy: 0.9873 - val_loss: 0.1113 - val_accuracy: 0.9639
# Epoch 56/120
# 3240/3240 [==============================] - 785s 242ms/step - loss: 0.0354 - accuracy: 0.9880 - val_loss: 0.1937 - val_accuracy: 0.9399
# Epoch 57/120
# 3240/3240 [==============================] - 780s 241ms/step - loss: 0.0346 - accuracy: 0.9883 - val_loss: 198.7455 - val_accuracy: 0.0039
# Epoch 58/120
# 3240/3240 [==============================] - 779s 240ms/step - loss: 0.0343 - accuracy: 0.9885 - val_loss: 220.8029 - val_accuracy: 0.0025
# Epoch 59/120
# 3240/3240 [==============================] - 779s 241ms/step - loss: 0.0344 - accuracy: 0.9884 - val_loss: 0.1774 - val_accuracy: 0.9457
# Epoch 60/120
# 3240/3240 [==============================] - 782s 241ms/step - loss: 0.0322 - accuracy: 0.9894 - val_loss: 207.8472 - val_accuracy: 0.0055
# Epoch 61/120
# 3240/3240 [==============================] - 802s 247ms/step - loss: 0.0335 - accuracy: 0.9889 - val_loss: 0.1149 - val_accuracy: 0.9629
# Epoch 62/120
# 3240/3240 [==============================] - 785s 242ms/step - loss: 0.0313 - accuracy: 0.9895 - val_loss: 238.1616 - val_accuracy: 0.0025
# Epoch 63/120
# 3240/3240 [==============================] - 784s 242ms/step - loss: 0.0317 - accuracy: 0.9893 - val_loss: 0.1077 - val_accuracy: 0.9664
# Epoch 64/120
# 3240/3240 [==============================] - 780s 241ms/step - loss: 0.0312 - accuracy: 0.9896 - val_loss: 222.6062 - val_accuracy: 0.0047
# Epoch 65/120
# 3240/3240 [==============================] - 790s 244ms/step - loss: 0.0310 - accuracy: 0.9896 - val_loss: 206.2885 - val_accuracy: 0.0033
# Epoch 66/120
# 3240/3240 [==============================] - 780s 241ms/step - loss: 0.0298 - accuracy: 0.9900 - val_loss: 9.2580 - val_accuracy: 0.2717
# Epoch 67/120
# 3240/3240 [==============================] - 792s 244ms/step - loss: 0.0281 - accuracy: 0.9906 - val_loss: 0.1133 - val_accuracy: 0.9648
# Epoch 68/120
# 3240/3240 [==============================] - 788s 243ms/step - loss: 0.0280 - accuracy: 0.9905 - val_loss: 0.1140 - val_accuracy: 0.9638
# Epoch 69/120
# 3240/3240 [==============================] - 783s 242ms/step - loss: 0.0292 - accuracy: 0.9905 - val_loss: 77.5472 - val_accuracy: 0.0306
# Epoch 70/120
# 3240/3240 [==============================] - 793s 245ms/step - loss: 0.0271 - accuracy: 0.9908 - val_loss: 246.2276 - val_accuracy: 0.0029
# Epoch 71/120
# 3240/3240 [==============================] - 795s 245ms/step - loss: 0.0272 - accuracy: 0.9910 - val_loss: 0.1087 - val_accuracy: 0.9659
# Epoch 72/120
# 3240/3240 [==============================] - 783s 242ms/step - loss: 0.0262 - accuracy: 0.9909 - val_loss: 0.1746 - val_accuracy: 0.9475
# Epoch 73/120
# 3240/3240 [==============================] - 830s 256ms/step - loss: 0.0269 - accuracy: 0.9912 - val_loss: 0.1486 - val_accuracy: 0.9550
# Epoch 74/120
# 3240/3240 [==============================] - 850s 262ms/step - loss: 0.0259 - accuracy: 0.9913 - val_loss: 151.7704 - val_accuracy: 0.0054
# Epoch 75/120
# 3240/3240 [==============================] - 867s 267ms/step - loss: 0.0250 - accuracy: 0.9918 - val_loss: 28.2539 - val_accuracy: 0.0745
# Epoch 76/120
# 3240/3240 [==============================] - 818s 252ms/step - loss: 0.0245 - accuracy: 0.9916 - val_loss: 215.8079 - val_accuracy: 0.0037
# Epoch 77/120
# 3240/3240 [==============================] - 801s 247ms/step - loss: 0.0249 - accuracy: 0.9918 - val_loss: 5.7399 - val_accuracy: 0.3823
# Epoch 78/120
# 3240/3240 [==============================] - 825s 255ms/step - loss: 0.0246 - accuracy: 0.9918 - val_loss: 205.1065 - val_accuracy: 0.0046
# Epoch 79/120
# 3240/3240 [==============================] - 817s 252ms/step - loss: 0.0246 - accuracy: 0.9920 - val_loss: 104.7366 - val_accuracy: 0.0225
# Epoch 80/120
# 3240/3240 [==============================] - 900s 278ms/step - loss: 0.0248 - accuracy: 0.9917 - val_loss: 0.0964 - val_accuracy: 0.9721
# Epoch 81/120
# 3240/3240 [==============================] - 889s 275ms/step - loss: 0.0235 - accuracy: 0.9921 - val_loss: 92.3437 - val_accuracy: 0.0194
# Epoch 82/120
# 3240/3240 [==============================] - 846s 261ms/step - loss: 0.0230 - accuracy: 0.9923 - val_loss: 0.1715 - val_accuracy: 0.9502
# Epoch 83/120
# 3240/3240 [==============================] - 819s 253ms/step - loss: 0.0220 - accuracy: 0.9928 - val_loss: 0.0742 - val_accuracy: 0.9769
# Epoch 84/120
# 3240/3240 [==============================] - 841s 260ms/step - loss: 0.0234 - accuracy: 0.9920 - val_loss: 233.8663 - val_accuracy: 0.0044
# Epoch 85/120
# 3240/3240 [==============================] - 835s 258ms/step - loss: 0.0223 - accuracy: 0.9924 - val_loss: 238.0931 - val_accuracy: 0.0044
# Epoch 86/120
# 3240/3240 [==============================] - 856s 264ms/step - loss: 0.0226 - accuracy: 0.9927 - val_loss: 0.1426 - val_accuracy: 0.9587
# Epoch 87/120
# 3240/3240 [==============================] - 846s 261ms/step - loss: 0.0220 - accuracy: 0.9925 - val_loss: 0.1151 - val_accuracy: 0.9655
# Epoch 88/120
# 3240/3240 [==============================] - 831s 256ms/step - loss: 0.0210 - accuracy: 0.9931 - val_loss: 0.0860 - val_accuracy: 0.9729
# Epoch 89/120
# 3240/3240 [==============================] - 840s 259ms/step - loss: 0.0211 - accuracy: 0.9930 - val_loss: 0.0664 - val_accuracy: 0.9791
# Epoch 90/120
# 3240/3240 [==============================] - 840s 259ms/step - loss: 0.0213 - accuracy: 0.9929 - val_loss: 0.0931 - val_accuracy: 0.9720
# Epoch 91/120
# 3240/3240 [==============================] - 855s 264ms/step - loss: 0.0217 - accuracy: 0.9928 - val_loss: 0.1197 - val_accuracy: 0.9647
# Epoch 92/120
# 3240/3240 [==============================] - 828s 255ms/step - loss: 0.0202 - accuracy: 0.9935 - val_loss: 0.1116 - val_accuracy: 0.9679
# Epoch 93/120
# 3240/3240 [==============================] - 798s 246ms/step - loss: 0.0213 - accuracy: 0.9929 - val_loss: 0.0912 - val_accuracy: 0.9713
# Epoch 94/120
# 3240/3240 [==============================] - 791s 244ms/step - loss: 0.0194 - accuracy: 0.9936 - val_loss: 0.0838 - val_accuracy: 0.9750
# Epoch 95/120
# 3240/3240 [==============================] - 786s 243ms/step - loss: 0.0195 - accuracy: 0.9936 - val_loss: 216.7301 - val_accuracy: 0.0025
# Epoch 96/120
# 3240/3240 [==============================] - 821s 253ms/step - loss: 0.0192 - accuracy: 0.9935 - val_loss: 51.7515 - val_accuracy: 0.0470
# Epoch 97/120
# 3240/3240 [==============================] - 834s 257ms/step - loss: 0.0193 - accuracy: 0.9936 - val_loss: 243.9012 - val_accuracy: 0.0036
# Epoch 98/120
# 3240/3240 [==============================] - 830s 256ms/step - loss: 0.0183 - accuracy: 0.9939 - val_loss: 0.0874 - val_accuracy: 0.9731
# Epoch 99/120
# 3240/3240 [==============================] - 839s 259ms/step - loss: 0.0193 - accuracy: 0.9936 - val_loss: 0.0955 - val_accuracy: 0.9711
# Epoch 100/120
# 3240/3240 [==============================] - 786s 243ms/step - loss: 0.0186 - accuracy: 0.9939 - val_loss: 239.1753 - val_accuracy: 0.0027
# Epoch 101/120
# 3240/3240 [==============================] - 789s 243ms/step - loss: 0.0181 - accuracy: 0.9940 - val_loss: 254.5885 - val_accuracy: 0.0025
# Epoch 102/120
# 3240/3240 [==============================] - 804s 248ms/step - loss: 0.0188 - accuracy: 0.9937 - val_loss: 225.9644 - val_accuracy: 0.0025
# Epoch 103/120
# 3240/3240 [==============================] - 788s 243ms/step - loss: 0.0184 - accuracy: 0.9939 - val_loss: 0.0762 - val_accuracy: 0.9765
# Epoch 104/120
# 3240/3240 [==============================] - 772s 238ms/step - loss: 0.0173 - accuracy: 0.9941 - val_loss: 94.6036 - val_accuracy: 0.0257
# Epoch 105/120
# 3240/3240 [==============================] - 788s 243ms/step - loss: 0.0179 - accuracy: 0.9941 - val_loss: 199.9338 - val_accuracy: 0.0025
# Epoch 106/120
# 3240/3240 [==============================] - 789s 243ms/step - loss: 0.0179 - accuracy: 0.9941 - val_loss: 0.0738 - val_accuracy: 0.9772
# Epoch 107/120
# 3240/3240 [==============================] - 807s 249ms/step - loss: 0.0175 - accuracy: 0.9944 - val_loss: 0.0894 - val_accuracy: 0.9750
# Epoch 108/120
# 3240/3240 [==============================] - 792s 245ms/step - loss: 0.0171 - accuracy: 0.9944 - val_loss: 168.8250 - val_accuracy: 0.0035
# Epoch 109/120
# 3240/3240 [==============================] - 787s 243ms/step - loss: 0.0173 - accuracy: 0.9942 - val_loss: 258.7214 - val_accuracy: 0.0030
# Epoch 110/120
# 3240/3240 [==============================] - 785s 242ms/step - loss: 0.0165 - accuracy: 0.9946 - val_loss: 3.2568 - val_accuracy: 0.5895
# Epoch 111/120
# 3240/3240 [==============================] - 811s 250ms/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 191.7908 - val_accuracy: 0.0025
# Epoch 112/120
# 3240/3240 [==============================] - 793s 245ms/step - loss: 0.0163 - accuracy: 0.9948 - val_loss: 264.3375 - val_accuracy: 0.0025
# Epoch 113/120
# 3240/3240 [==============================] - 787s 243ms/step - loss: 0.0166 - accuracy: 0.9946 - val_loss: 0.0787 - val_accuracy: 0.9777
# Epoch 114/120
# 3240/3240 [==============================] - 800s 247ms/step - loss: 0.0165 - accuracy: 0.9946 - val_loss: 0.0896 - val_accuracy: 0.9746
# Epoch 115/120
# 3240/3240 [==============================] - 794s 245ms/step - loss: 0.0155 - accuracy: 0.9948 - val_loss: 0.0901 - val_accuracy: 0.9736
# Epoch 116/120
# 3240/3240 [==============================] - 795s 245ms/step - loss: 0.0169 - accuracy: 0.9946 - val_loss: 0.0716 - val_accuracy: 0.9787
# Epoch 117/120
# 3240/3240 [==============================] - 792s 244ms/step - loss: 0.0148 - accuracy: 0.9951 - val_loss: 264.4795 - val_accuracy: 0.0025
# Epoch 118/120
# 3240/3240 [==============================] - 799s 247ms/step - loss: 0.0166 - accuracy: 0.9946 - val_loss: 267.3108 - val_accuracy: 0.0025
# Epoch 119/120
# 3240/3240 [==============================] - 780s 241ms/step - loss: 0.0148 - accuracy: 0.9951 - val_loss: 0.1477 - val_accuracy: 0.9590
# Epoch 120/120
# 3240/3240 [==============================] - 797s 246ms/step - loss: 0.0159 - accuracy: 0.9947 - val_loss: 0.0773 - val_accuracy: 0.9776

# %%
loss = history.history['loss'] # training loss
val_loss = history.history['val_loss'] # validation loss

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Add maximum and minimum values for training loss
max_loss = max(loss)
min_loss = min(loss)
max_loss_epoch = loss.index(max_loss) + 1
min_loss_epoch = loss.index(min_loss) + 1

plt.annotate(f'Train Max: {max_loss:.4f}', xy=(max_loss_epoch, max_loss), xytext=(max_loss_epoch, max_loss+1),
             arrowprops=dict(facecolor='black', arrowstyle='->'), bbox=dict(facecolor='white', edgecolor='black', boxstyle='round'), horizontalalignment='center')
plt.annotate(f'Train Min: {min_loss:.4f}', xy=(min_loss_epoch, min_loss), xytext=(min_loss_epoch, min_loss+1),
             arrowprops=dict(facecolor='black', arrowstyle='->'), bbox=dict(facecolor='white', edgecolor='black', boxstyle='round'), horizontalalignment='center')

# Add maximum and minimum values for validation loss
max_val_loss = max(val_loss)
min_val_loss = min(val_loss)    
max_val_loss_epoch = val_loss.index(max_val_loss) + 1
min_val_loss_epoch = val_loss.index(min_val_loss) + 1

plt.annotate(f'Val Max: {max_val_loss:.4f}', xy=(max_val_loss_epoch, max_val_loss), xytext=(max_val_loss_epoch+2, max_val_loss+1),
             arrowprops=dict(facecolor='black', arrowstyle='->'), bbox=dict(facecolor='white', edgecolor='black', boxstyle='round'), horizontalalignment='center')
plt.annotate(f'Val Min: {min_val_loss:.4f}', xy=(min_val_loss_epoch, min_val_loss), xytext=(min_val_loss_epoch, min_val_loss+1.3),
             arrowprops=dict(facecolor='black', arrowstyle='->'), bbox=dict(facecolor='white', edgecolor='black', boxstyle='round'), horizontalalignment='center')

plt.ylim(0, 7)  # Set the y-axis limits between 0 and 1

plt.show()

# %%
acc = history.history['accuracy'] # training accuracy
val_acc = history.history['val_accuracy'] # validation accuracy

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Add maximum and minimum values for training accuracy
max_acc = max(acc)
min_acc = min(acc)
max_acc_epoch = acc.index(max_acc) + 1
min_acc_epoch = acc.index(min_acc) + 1

plt.annotate(f'Train Max: {max_acc:.4f}', xy=(max_acc_epoch, max_acc), xytext=(max_acc_epoch, max_acc-0.1),
             arrowprops=dict(facecolor='black', arrowstyle='->'), bbox=dict(facecolor='white', edgecolor='black', boxstyle='round'), horizontalalignment='center')
plt.annotate(f'Train Min: {min_acc:.4f}', xy=(min_acc_epoch, min_acc), xytext=(min_acc_epoch, min_acc+0.1),
             arrowprops=dict(facecolor='black', arrowstyle='->'), bbox=dict(facecolor='white', edgecolor='black', boxstyle='round'), horizontalalignment='center')

# Add maximum and minimum values for validation accuracy
max_val_acc = max(val_acc)
min_val_acc = min(val_acc)
max_val_acc_epoch = val_acc.index(max_val_acc) + 1
min_val_acc_epoch = val_acc.index(min_val_acc) + 1

plt.annotate(f'Val Max: {max_val_acc:.4f}', xy=(max_val_acc_epoch, max_val_acc), xytext=(max_val_acc_epoch-10, max_val_acc-0.2),
             arrowprops=dict(facecolor='black', arrowstyle='->'), bbox=dict(facecolor='white', edgecolor='black', boxstyle='round'), horizontalalignment='center')
plt.annotate(f'Val Min: {min_val_acc:.4f}', xy=(min_val_acc_epoch, min_val_acc), xytext=(min_val_acc_epoch-10, min_val_acc+0.2),
             arrowprops=dict(facecolor='black', arrowstyle='->'), bbox=dict(facecolor='white', edgecolor='black', boxstyle='round'), horizontalalignment='center')

plt.show()

# %%
# 모델 저장
# model.save('E:\Pill Project\model/AlexNet_10_31_data18_batch16_epoch30_m2.h5')

SAVED_MODEL_PATH = 'E:\Pill Project\model_h5/MobileNet_11_10_data400_batch32_epoch120_m1.h5'
export_path = os.path.join(SAVED_MODEL_PATH)

tf.keras.models.save_model(
  model,
  export_path,
  overwrite=True,
  include_optimizer=True,
  save_format=None,
  signatures=None,
  options=None
)
print('\nSaved model:')
# Out:
# Saved model:

# %%
# 저장된 모델 파일 로드
model = models.load_model('c:/Users/LEE/Desktop/app/assets/AlexNet_10_31_data18_batch16_epoch30_m1.tflite')

# %%
# 테스트셋 평가
results = model.evaluate(test_generator)
results
# Out:
# 405/405 [==============================] - 105s 258ms/step - loss: 0.3269 - accuracy: 0.9201
# [0.3269144296646118, 0.9200617074966431]

# %%
# 테스트셋 예측
results = model.predict(test_generator)
results
# Out:
# array([[0.0000000e+00, 6.7517599e-34, 0.0000000e+00, ..., 0.0000000e+00,
#         5.4453811e-36, 6.4441246e-26],
#        [4.7104237e-30, 2.4400703e-26, 3.8407118e-29, ..., 1.4998909e-21,
#         1.2567253e-27, 1.2149968e-20],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 1.7676101e-31],
#        ...,
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 5.4061440e-34, 0.0000000e+00, ..., 0.0000000e+00,
#         1.3848214e-26, 2.4400465e-38],
#        [2.7035816e-23, 1.8130349e-10, 1.7338660e-20, ..., 9.5538569e-30,
#         6.7365394e-28, 1.1803977e-27]], dtype=float32)

# %%
# 예측값을 인덱스로 변환
results = np.argmax(results, 1)
results
# Out:
# array([386, 280, 194, ...,  98, 102, 117], dtype=int64)

# %%
# 테스트셋에서 배치를 생성
for data_batch, labels_batch in test_generator:
    break
    
# 테스트셋의 첫 번째 이미지 출력
image = data_batch[0]

plt.imshow(image)
plt.show()

# %%
# 테스트셋 배치 데이터를 예측
results = model.predict(data_batch)

# 테스트셋의 첫 번째 라벨 이름 출력
labels_list[np.argmax(results[0])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# e:\Pill Project\code\Model\AlexNet_Train.ipynb 셀 25 line 5
#       <a href='vscode-notebook-cell:/e%3A/Pill%20Project/code/Model/AlexNet_Train.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a> results = model.predict(data_batch)
#       <a href='vscode-notebook-cell:/e%3A/Pill%20Project/code/Model/AlexNet_Train.ipynb#X33sZmlsZQ%3D%3D?line=3'>4</a> # 테스트셋의 첫 번째 라벨 이름 출력
# ----> <a href='vscode-notebook-cell:/e%3A/Pill%20Project/code/Model/AlexNet_Train.ipynb#X33sZmlsZQ%3D%3D?line=4'>5</a> labels_list[np.argmax(results[0])]
#
# NameError: name 'labels_list' is not defined
